# %%
import seaborn as sns
import pandas as pd
import numpy as np
#df=sns.load_dataset('orders.csv')
df=pd.read_csv('products.csv')

# %%
import dtale
dtale.show(df)
# Out:
# /home/shemaya/anaconda3/lib/python3.9/site-packages/dtale/views.py:755: FutureWarning:
#
# ['brand', 'brands', 'conformityCertificateFile', 'dimension.unit', 'keyDetails.keyDetail2', 'keyDetails.keyDetail3', 'productDataSheet', 'productType', 'warrantyFileSource', 'warrantyInformation', 'weight.unit'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#         <iframe
#             width="100%"
#             height="475"
#             src="http://shemaya-ProBook-440-G6:40001/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# /home/shemaya/anaconda3/lib/python3.9/site-packages/dtale/views.py:1996: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# 2023-02-08 12:18:46,008 - WARNING  - findfont: Font family 'Heiti TC' not found.
# ...
