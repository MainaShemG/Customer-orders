# %% [markdown]
# # DTALE library

# %%
# !pip install dtale
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 1.1 MB/s eta 0:00:00m eta 0:00:010:00:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 642.7/642.7 kB 976.3 kB/s eta 0:00:00m eta 0:00:010:01:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 565.9 kB/s eta 0:00:0031m1.5 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 1.0 MB/s eta 0:00:00m eta 0:00:010:00:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 1.1 MB/s eta 0:00:00m eta 0:00:010:00:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 1.0 MB/s eta 0:00:00m eta 0:00:010:00:02m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 577.7 kB/s eta 0:00:0036m0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 1.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...

# %%
import seaborn as sns
import pandas as pd
import numpy as np
#df=sns.load_dataset('orders.csv')
df=pd.read_csv('orders.csv')

# %%
import dtale
dtale.show(df)
# Out:
# /home/shemaya/anaconda3/lib/python3.9/site-packages/dtale/views.py:755: FutureWarning:
#
# ['client.devicetoken', 'client.email', 'client.firstName', 'client.lastName', 'client.location', 'client.user-name', 'client.userName', 'feduid', 'requestId', 'status', 'transactions'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#         <iframe
#             width="100%"
#             height="475"
#             src="http://shemaya-ProBook-440-G6:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # pandas profiling

# %%
# !pip install pandas-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 782.6 kB/s eta 0:00:000:00:010:00:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.5/344.5 kB 824.9 kB/s eta 0:00:000:00:010:00:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 1.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 1.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.8/679.8 kB 1.3 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 1.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 1.0 MB/s eta 0:00:001.7 MB/s eta 0:00:01
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27096 sha256=1186aab8a50bc9f4e910ac683f1ee18435384861b519656b4c7015ef17105099
# ...

# %%
import seaborn as sns
import pandas as pd
data=pd.read_csv('orders.csv')

# %%
# !pip install klib
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip

# %%
import seaborn as sns
import pandas as pd
df1=pd.read_csv('orders.csv')

# %%
import klib

# %%
# klib.describe - functions for visualizing datasets
#klib.cat_plot(df1) # returns a visualization of the number and frequency of categorical features
#klib.corr_mat(df1) # returns a color-encoded correlation matrix
#klib.corr_plot(df1) # returns a color-encoded heatmap, ideal for correlations
#klib.dist_plot(df1) # returns a distribution plot for every numeric feature
#klib.missingval_plot(df1) # returns a figure containing information about missing values

# %%
# klib.clean - functions for cleaning datasets
- klib.data_cleaning(df) # performs datacleaning (drop duplicates & empty rows/cols, adjust dtypes,...)
- klib.clean_column_names(df) # cleans and standardizes column names, also called inside data_cleaning()
- klib.convert_datatypes(df) # converts existing to more efficient dtypes, also called inside data_cleaning()
- klib.drop_missing(df) # drops missing values, also called in data_cleaning()
- klib.mv_col_handling(df) # drops features with high ratio of missing vals based on informational content
- klib.pool_duplicate_subsets(df) # pools subset of cols based on duplicates with min. loss of information

# %%
klib.data_cleaning(df1) # performs datacleaning (drop duplicates & empty rows/cols, adjust dtypes,...)
# Out:
# Shape of cleaned data: (253, 26) - Remaining NAs: 700
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 6
#      of which 1 single valued.     Columns: ['logistic_partner']
# Dropped missing values: 1260
# Reduced memory by at least: 0.02 MB (-33.33%)
#                            id     timestamp    amount  amount_paid  \
# 0    62f59344c54b5c6d41230c5c           NaN         1          1.0
# 1    63037e95a7710869f32a816b           NaN         1          0.0
# 2    630384c180aa506788bb0c4b           NaN         1          0.0
# 3    63047c4dfc6e5374c7e9a0e4           NaN         1          0.0
# 4    630498b762568e5a54327bdd           NaN    100000          0.0
# ..                        ...           ...       ...          ...
# 248  63d276a9e3d6367770a65b74  1.674737e+12         1          0.0
# 249  63d7aef26f917d5438bcedf1  1.675079e+12         3          0.0
# 250  63d7b0546f917d5438bcedf6  1.675080e+12  20456789          0.0
# ...

# %%
klib.clean_column_names(df1) # cleans and standardizes column names, also called inside data_cleaning()
# Out:
# Duplicate column names detected! Columns with index [19, 22] and names ['client_phone_number', 'client_user_name']) have been renamed to ['client_phone_number_19', 'client_user_name_22'].
#                            id     timestamp    amount  amount_paid  \
# 0    62f59344c54b5c6d41230c5c           NaN         1          1.0
# 1    63037e95a7710869f32a816b           NaN         1          0.0
# 2    630384c180aa506788bb0c4b           NaN         1          0.0
# 3    63047c4dfc6e5374c7e9a0e4           NaN         1          0.0
# 4    630498b762568e5a54327bdd           NaN    100000          0.0
# ..                        ...           ...       ...          ...
# 248  63d276a9e3d6367770a65b74  1.674737e+12         1          0.0
# 249  63d7aef26f917d5438bcedf1  1.675079e+12         3          0.0
# 250  63d7b0546f917d5438bcedf6  1.675080e+12  20456789          0.0
# 251  63d7b16d6f917d5438bcedfd  1.675080e+12     19599          0.0
# ...

# %%
klib.convert_datatypes(df1) # converts existing to more efficient dtypes, also called inside data_cleaning()
# Out:
#                            id     timestamp    amount  amount_paid  \
# 0    62f59344c54b5c6d41230c5c           NaN         1          1.0
# 1    63037e95a7710869f32a816b           NaN         1          0.0
# 2    630384c180aa506788bb0c4b           NaN         1          0.0
# 3    63047c4dfc6e5374c7e9a0e4           NaN         1          0.0
# 4    630498b762568e5a54327bdd           NaN    100000          0.0
# ..                        ...           ...       ...          ...
# 248  63d276a9e3d6367770a65b74  1.674737e+12         1          0.0
# 249  63d7aef26f917d5438bcedf1  1.675079e+12         3          0.0
# 250  63d7b0546f917d5438bcedf6  1.675080e+12  20456789          0.0
# 251  63d7b16d6f917d5438bcedfd  1.675080e+12     19599          0.0
# 252  63d7b3666f917d5438bcedff  1.675080e+12         3          0.0
#
#                   client_date                 client_id  client_timestamp  \
# 0    2022-07-31T10:49:45.887Z  62e65e49e0340324e47c7938     1659264585887
# ...

# %%
klib.drop_missing(df1) # drops missing values, also called in data_cleaning()
# Out:
#                            id     timestamp    amount  amount_paid  \
# 0    62f59344c54b5c6d41230c5c           NaN         1          1.0
# 1    63037e95a7710869f32a816b           NaN         1          0.0
# 2    630384c180aa506788bb0c4b           NaN         1          0.0
# 3    63047c4dfc6e5374c7e9a0e4           NaN         1          0.0
# 4    630498b762568e5a54327bdd           NaN    100000          0.0
# ..                        ...           ...       ...          ...
# 248  63d276a9e3d6367770a65b74  1.674737e+12         1          0.0
# 249  63d7aef26f917d5438bcedf1  1.675079e+12         3          0.0
# 250  63d7b0546f917d5438bcedf6  1.675080e+12  20456789          0.0
# 251  63d7b16d6f917d5438bcedfd  1.675080e+12     19599          0.0
# 252  63d7b3666f917d5438bcedff  1.675081e+12         3          0.0
#
#                   client_date                 client_id  client_timestamp  \
# 0    2022-07-31T10:49:45.887Z  62e65e49e0340324e47c7938     1659264585887
# ...

# %%
klib.mv_col_handling(df1) # drops features with high ratio of missing vals based on informational content
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 klib.mv_col_handling(df1)
#
# File ~/anaconda3/lib/python3.9/site-packages/klib/clean.py:431, in mv_col_handling(data, target, mv_threshold, corr_thresh_features, corr_thresh_target, return_details)
#     429 data_temp = data_local.copy()
#     430 for col in cols_mv:
# --> 431     corrmat = corr_mat(data_temp, colored=False)
#     432     if abs(corrmat[col]).nlargest(2)[1] > corr_thresh_features:
#     433         high_corr_features.append(col)
#
# File ~/anaconda3/lib/python3.9/site-packages/klib/describe.py:246, in corr_mat(data, split, threshold, target, method, colored)
#     243     corr.columns = [target]
#     245 else:
# --> 246     corr = data.corr(method=method, numeric_only=True)
#     248 corr = _corr_selector(corr, split=split, threshold=threshold)
#     250 if colored:
# ...
