# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv('reviews.csv')
data
# Out:
#                           _id              client._date  \
# 0    6304992b62568e5a54327bde  2022-07-31T10:49:45.887Z
# 1    63049e4662568e5a54327be1  2022-07-31T10:49:45.887Z
# 2    6304bd3235ab184215ac2037  2022-07-31T10:49:45.887Z
# 3    6304bd5635ab184215ac2038  2022-07-31T10:49:45.887Z
# 4    6305dedf944a0412c9a50bd9  2022-07-31T10:49:45.887Z
# ..                        ...                       ...
# 209  63c509a3f47e7f559bdbfb21  2023-01-16T06:29:29.623Z
# 210  63cb8a6ef47e7f559bdbfbd9  2023-01-16T06:29:29.623Z
# 211  63cb9cb0f47e7f559bdbfbda  2023-01-16T06:29:29.623Z
# 212  63cfb7dc7b93ef1c7255916b  2022-07-31T10:49:45.887Z
# 213  63d7961d6f917d5438bcede4  2023-01-24T12:58:19.989Z
#
#                    client._id  client._timestamp client.active  \
# 0    62e65e49e0340324e47c5948       1.659265e+12           NaN
# 1    62e65e49e0340324e47c5948       1.659265e+12           NaN
# 2    62e65e49e0340324e47c5948       1.659265e+12           NaN
# ...

# %%
data.columns
# Out:
# Index(['_id', 'client._date', 'client._id', 'client._timestamp',
#        'client.active', 'client.approved', 'client.email', 'client.feduid',
#        'client.firstName', 'client.lastName', 'client.location',
#        'client.phoneNumber', 'client.roles', 'client.userName', 'clientid',
#        'downvote', 'email', 'likes', 'name', 'partner', 'productId', 'rating',
#        'review', 'reviewedShop', 'upvote', 'vote'],
#       dtype='object')

# %%
data.shape
# Out:
# (214, 26)

# %%
data['review'].unique()
# Out:
# array(['Nice product', 'Nice', 'Awsome', 'Very nice', 'Wonderful',
#        'Great!', 'very nice service etc',
#        'This is a very nice shop that sells quality and affordable goods',
#        'The customer services is excellent which makes it my number shop',
#        'The customer services is excellent which makes it my number shop, The best shop ever',
#        'Dghk', 'Ghjkllh', 'Ghjklg', 'Saraj', 'Dghvbnmkh', 'Dghhjjjfd',
#        'Hhgfdddfhb', nan, 'High quality product', 'Cool product',
#        'Very powerful engine', 'Very nice car',
#        'faster deliveries am impressed',
#        "Lorem Ipsum has been the industry's standard dummy text ever since the 1500s",
#        'Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi',
# ...

# %%
data['review'].nunique()
# Out:
# 105

# %%
data['review'].value_counts()
# Out:
# Nice product                                                                                                                                                                                                                           0.096774
# very nice service etc                                                                                                                                                                                                                  0.096774
# Nice                                                                                                                                                                                                                                   0.064516
#  If you are going to use a passage of Lorem Ipsum, you need to be sure there isn't anything embarrassing hidden in the middle of text. All the Lorem Ipsum generators on the Internet tend to repeat predefined chunks as necessary    0.053763
# ...

# %%
data.groupby('review')['upvote'].value_counts().sort_values(ascending=False)
# Out:
# review                                                                        upvote
# Nice product                                                                   1.0      3
# Lorem Ipsum has been the industry's standard dummy text ever since the 1500s   1.0      2
# Nice                                                                           1.0      2
# Nice product                                                                   2.0      2
# nice                                                                           2.0      1
# kazi safi                                                                      1.0      1
# fgghjjkkkkkkk                                                                  1.0      1
# cool guy brought snacks with him highly recommend                             -4.0      1
# Woow!!                                                                         0.0      1
# ...
